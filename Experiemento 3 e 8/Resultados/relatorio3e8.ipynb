# %%
import pandas as pd
import seaborn as srn
import statistics  as sts
import matplotlib.pyplot as plt
import numpy as np

# %%
dados = pd.read_csv('Curvas resfriamento Pb-Sn.csv',sep=';')
dados.head()
# Out:
#    Tempo   Temperatura  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      1         380.7       358.1       361.5       386.9       357.3
# 1      2         380.4       357.9       361.4       388.1       356.9
# 2      3         380.1       357.6       361.3       388.5       356.8
# 3      4         379.8       357.4       361.3       388.5       356.7
# 4      5         379.5       357.1       361.3       388.2       356.4
#
#    Unnamed: 6
# 0       390.4
# 1       389.4
# 2       389.1
# 3       389.0
# 4       389.5

# %%
dados.columns = ["Tempo (s)", "Amostra 1", "Amostra 2", "Amostra 3", "Amostra 4", "Amostra 5", "Amostra 6"]
dados.head()
# Out:
#    Tempo (s)  Amostra 1  Amostra 2  Amostra 3  Amostra 4  Amostra 5  Amostra 6
# 0          1      380.7      358.1      361.5      386.9      357.3      390.4
# 1          2      380.4      357.9      361.4      388.1      356.9      389.4
# 2          3      380.1      357.6      361.3      388.5      356.8      389.1
# 3          4      379.8      357.4      361.3      388.5      356.7      389.0
# 4          5      379.5      357.1      361.3      388.2      356.4      389.5

# %%
plotAmostra1 = plt.scatter(x=dados.iloc[:,0],y=dados.iloc[:,1],s=1)
plt.title("Resfriamento Amostra 1")
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (°C)')
# Out:
# Text(0, 0.5, 'Temperatura (°C)')

# %%
plotAmostra2 = plt.scatter(x=dados.iloc[:,0],y=dados.iloc[:,2],s=1)
plt.title("Resfriamento Amostra 2")
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (°C)')
# Out:
# Text(0, 0.5, 'Temperatura (°C)')

# %%
plotAmostra3 = plt.scatter(x=dados.iloc[:,0],y=dados.iloc[:,3],s=1)
plt.title("Resfriamento Amostra 3")
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (°C)')
# Out:
# Text(0, 0.5, 'Temperatura (°C)')

# %%
plotAmostra4 = plt.scatter(x=dados.iloc[:,0],y=dados.iloc[:,4],s=1)
plt.title("Resfriamento Amostra 4")
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (°C)')
# Out:
# Text(0, 0.5, 'Temperatura (°C)')

# %%
plotAmostra5 = plt.scatter(x=dados.iloc[:,0],y=dados.iloc[:,5],s=1)
plt.title("Resfriamento Amostra 5")
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (°C)')
# Out:
# Text(0, 0.5, 'Temperatura (°C)')

# %%
plotAmostra6 = plt.scatter(x=dados.iloc[:,0],y=dados.iloc[:,6],s=1)
plt.title("Resfriamento Amostra 6")
plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (°C)')
# Out:
# Text(0, 0.5, 'Temperatura (°C)')
