# %%
import pandas as pd
import seaborn as srn
import statistics  as sts
import matplotlib.pyplot as plt
import numpy as np

# %%
liga2024EN = pd.read_csv("liga2024envnatural.csv",sep=";")
liga2024EA = pd.read_csv("liga2024envartificial.csv",sep=";")
liga6351EN = pd.read_csv("liga6351envnatural.csv",sep=";")
liga6351EA = pd.read_csv("liga6351envarticial.csv",sep=";")

# %%
plt.figure(1)
plt.subplot(2,2,1)
plt.plot(liga2024EN.iloc[0,1:])
plt.plot(liga2024EN.iloc[1,1:])
plt.plot(liga2024EN.iloc[2,1:])
srn.boxplot(data = liga2024EN.iloc[:,1:6],color='grey')
plt.subplot(2,2,2)
plt.plot(liga2024EA.iloc[0,1:])
plt.plot(liga2024EA.iloc[1,1:])
plt.plot(liga2024EA.iloc[2,1:])
srn.boxplot(data = liga2024EA.iloc[:,1:5],color='grey')
plt.subplot(2,2,3)
plt.plot(liga6351EN.iloc[0,1:])
plt.plot(liga6351EN.iloc[1,1:])
plt.plot(liga6351EN.iloc[2,1:])
srn.boxplot(data = liga6351EN.iloc[:,1:6],color='grey')
plt.subplot(2,2,4)
plt.plot(liga6351EA.iloc[0,1:])
plt.plot(liga6351EA.iloc[1,1:])
plt.plot(liga6351EA.iloc[2,1:])
srn.boxplot(data = liga6351EA.iloc[:,1:5],color='grey')
# Out:
# <AxesSubplot:>

# %%
mean2024EN = liga2024EN.iloc[0:3,1:6].mean()
mean2024EA = liga2024EA.iloc[0:3,1:5].mean()
mean6351EN = liga6351EN.iloc[0:3,1:6].mean()
mean6351EA = liga6351EA.iloc[0:3,1:5].mean()

# %%
plt.figure(1)
plt.subplot(2,2,1)
plt.plot(mean2024EN)
srn.boxplot(data = liga2024EN.iloc[:,1:6])
plt.subplot(2,2,2)
plt.plot(mean2024EA)
srn.boxplot(data = liga2024EA.iloc[:,1:5])
plt.subplot(2,2,3)
plt.plot(mean6351EN)
srn.boxplot(data = liga6351EN.iloc[:,1:6])
plt.subplot(2,2,4)
plt.plot(mean6351EA)
srn.boxplot(data = liga6351EA.iloc[:,1:5])
# Out:
# <AxesSubplot:>

# %%
plt.plot(liga2024EN.iloc[0,1:6])
